# %%
import pandas as pd
import numpy as np
import json

# %%
target = pd.read_csv('Dataset/main/recovery-news-data.csv')

source = pd.read_csv('Dataset/metadata_final/ExtractedData_ReCovery.csv')

# %%
target.head()
# Out:
#    news_id                                                url  \
# 0        0  https://www.nytimes.com/article/what-is-corona...
# 1        1  https://www.npr.org/2020/01/22/798392172/chine...
# 2        2  https://www.theverge.com/2020/1/23/21078457/co...
# 3        3  https://www.worldhealth.net/news/novel-coronav...
# 4        4  https://www.theverge.com/2020/1/24/21080845/co...
#
#                      publisher publish_date  \
# 0           The New York Times   2020-01-21
# 1  National Public Radio (NPR)   2020-01-22
# 2                    The Verge   2020-01-23
# 3              WorldHealth.Net   2020-01-24
# 4                    The Verge   2020-01-24
#
#                                               author  \
# 0               ['Knvul Sheikh', 'Roni Caryn Rabin']
# 1                                     ['Emily Feng']
# 2                                 ['Nicole Wetsman']
# 3                                                 []
# ...

# %%
target_info = target.iloc[:,[1,7,12]].values

# %%
target_info
# Out:
# array([['https://www.nytimes.com/article/what-is-coronavirus.html',
# ...

# %%
source.head()
# Out:
#    Unnamed: 0  numSources                                            img_url  \
# 0           0           4  https://static01.nyt.com/images/2020/03/12/sci...
# 1           1           4  https://media.npr.org/include/images/facebook-...
# 2           2           4  https://cdn.vox-cdn.com/thumbor/a9_Oz7cvSBKyal...
# 3           3           4  https://www.worldhealth.net/media/original_ima...
# 4           4           4  https://cdn.vox-cdn.com/thumbor/t2gt1SmEni4Mcr...
#
#                                              source1  \
# 0  https://www.dw.com/pt-br/covid-19-matou-115-mi...
# 1                https://en.wikipedia.org/wiki/Music
# 2             https://en.wikipedia.org/wiki/Language
# 3  https://www.mayoclinic.org/diseases-conditions...
# 4  https://www.theverge.com/2021/5/23/22449898/in...
#
#                                                text1  \
# 0  D̻ uma olhada exclusiva na verṣo beta da no...
# 1  \n Music is the art of arranging sounds in tim...
# ...

# %%
source_info = source.iloc[:,:].values

# %%
source_info
# Out:
# array([[0, 4,
#         'https://static01.nyt.com/images/2020/03/12/science/26VIRUS-EXPLAINER-update1/26VIRUS-EXPLAINER-update1-facebookJumbo.jpg',
#         ...,
#         'https://www.thephuketnews.com/no-coronavirus-isnt-the-same-as-the-flu-75267.php',
# ...

# %%
print(type(target_info),type(source_info))

print(target_info.shape,source_info.shape)
# Out:
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# (2029, 3) (2029, 15)

# %% [markdown]
# # Importing Source Reliability Data

# %%
with open('Dataset/MBFC/factuality.json') as f:
    data = json.load(f)

def reliability(dict, key):
    
    if key in dict.keys():
        return dict[key]
    else:
        return 'UNKNOWN'
    
dict = {}
for p in data:
    pos = 0
    for i in range(len(p)):
        if p[i] == '.':
            pos = i
            break
    dict[p[:pos]] = data[p]
    
def reliability_from_link(link):
    
    url = str(link)
    
    if len(url)<4:
        return 'UNKNOWN'

    if url[:5] == 'https':
        url = url[8:]
    else:
        url = url[7:]

    pos = 0
    for i in range(len(url)):
        if url[i] == '.':
            pos = i
            break
    
    if reliability(dict,url[:pos]) != 'UNKNOWN':
        return reliability(dict,url[:pos])

    url = url[pos+1:]

    pos = len(url)
    for i in range(len(url)):
        if url[i] == '.':
            pos = i
            break
    
    if reliability(dict,url[:pos]) != 'UNKNOWN':
        return reliability(dict,url[:pos])
    else:
        return 'UNKNOWN'

# %%
def get_label(org):
    
    org = str(org)
    
    if org == 'mixture':
        return org
    
    if org=='real' or org=='1' or org == 'TRUE' or org=='True' or org=='true':
        return 'REAL'
    if org=='fake' or org=='0' or org == 'FALSE' or org=='False' or org=='false':
        return 'FAKE'
    
    print('New Label Found: ',org)
    
    return org

# %%
source_data = []
target_data = []

def filter(index):
    
    if source_info[index][1] == 0:
        return
    
    label = get_label(target_info[index][2])
    if label == 'mixture':
        return
    
    temp = []
    temp1 = []
    
    temp1.append('Rcv' + str(source_info[index][0])) # id representing instance from original data
    temp1.append(target_info[index][0]) # target url
#     temp1.append('https://www.reuters.com/') # target url
    temp1.append(target_info[index][1]) # target text
    temp1.append(source_info[index][2]) # image url
    temp1.append(label) # target label
    
    target_data.append(temp1)
    
    temp.append('Rcv' + str(source_info[index][0])) # id representing instance from original data
    temp.append(source_info[index][1]) # numSources
    
    for i in range(3,15,3):
            
        temp.append(source_info[index][i])    # Source_url
        temp.append(source_info[index][i+1])  # Source_text
        temp.append(source_info[index][i+2])  # Source_imge_url
        temp.append(reliability_from_link(source_info[index][i])) # Source_reliability
    
    source_data.append(temp)

# %%
for i in range(len(source_info)):
    filter(i)

# %%
source_data[0]
# Out:
# ['Rcv0',
#  4,
#  'https://www.dw.com/pt-br/covid-19-matou-115-mil-profissionais-de-sa%C3%BAde-no-mundo-estima-oms/a-57648381',
# ...

# %%
target_data[0]
# Out:
# ['Rcv0',
#  'https://www.nytimes.com/article/what-is-coronavirus.html',
# ...

# %%
print('Total instances: ' , len(source_info), ', Final instances: ' , len(source_data))
# Out:
# Total instances:  2029 , Final instances:  1869

# %%
df = pd.DataFrame(source_data, columns =['ID', 'numSources','Source_url1','Source_text1','Image_url1','Source_reliability1','Source_url2','Source_text2','Image_url2','Source_reliability2','Source_url3','Source_text3','Image_url3','Source_reliability3','Source_url4','Source_text4','Image_url4','Source_reliability4'])

df1 = pd.DataFrame(target_data, columns =['ID','Target_url','Target_text', 'Image_url', 'label'])

# %%
df
# Out:
#            ID  numSources                                        Source_url1  \
# 0        Rcv0           4  https://www.dw.com/pt-br/covid-19-matou-115-mi...
# 1        Rcv1           4                https://en.wikipedia.org/wiki/Music
# 2        Rcv2           4             https://en.wikipedia.org/wiki/Language
# 3        Rcv3           4  https://www.mayoclinic.org/diseases-conditions...
# 4        Rcv4           4  https://www.theverge.com/2021/5/23/22449898/in...
# ...       ...         ...                                                ...
# 1864  Rcv2019           3  https://www.weforum.org/agenda/2020/04/high-no...
# 1865  Rcv2020           4            https://en.wikipedia.org/wiki/Arecaceae
# 1866  Rcv2021           4             https://en.wikipedia.org/wiki/Language
# 1867  Rcv2025           3  https://en.wikipedia.org/wiki/Gentleman_(1993_...
# 1868  Rcv2027           4             https://en.wikipedia.org/wiki/Language
#
# ...

# %%
df1
# Out:
#            ID                                         Target_url  \
# 0        Rcv0  https://www.nytimes.com/article/what-is-corona...
# 1        Rcv1  https://www.npr.org/2020/01/22/798392172/chine...
# 2        Rcv2  https://www.theverge.com/2020/1/23/21078457/co...
# 3        Rcv3  https://www.worldhealth.net/news/novel-coronav...
# 4        Rcv4  https://www.theverge.com/2020/1/24/21080845/co...
# ...       ...                                                ...
# 1864  Rcv2019  http://widerimage.reuters.com/story/high-noon-...
# 1865  Rcv2020  http://widerimage.reuters.com/story/in-cambodi...
# 1866  Rcv2021  https://www.washingtonpost.com/graphics/2020/w...
# 1867  Rcv2025  https://www.vanityfair.com/news/2020/05/after-...
# 1868  Rcv2027  https://www.fox5ny.com/news/nearly-half-of-twi...
#
#                                             Target_text  \
# 0     \nA novel respiratory virus that originated in...
# 1     Chinese Health Officials: More Die From Newly ...
# ...

# %%
df.to_csv('Dataset/Initial_Data/Source/ReCovery.csv')

df1.to_csv('Dataset/Initial_Data/Target/ReCovery.csv')
