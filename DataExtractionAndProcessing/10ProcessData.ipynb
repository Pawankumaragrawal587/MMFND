# %%
import numpy as np
import pandas as pd
from ast import literal_eval

# %%
target = pd.read_csv('Dataset/Initial_Data/Target/TICNN.csv')

target
# Out:
#       Unnamed: 0        ID                                         Target_url  \
# 0              0      Tcn0  https://www.nytimes.com/2016/11/22/us/politics...
# 1              1      Tcn2  https://www.nytimes.com/2016/11/12/us/politics...
# 2              2      Tcn3  https://www.nytimes.com/2016/10/21/business/in...
# 3              3      Tcn4  https://www.nytimes.com/2016/11/21/us/politics...
# 4              4      Tcn5  https://www.nytimes.com/2016/11/19/us/politics...
# ...          ...       ...                                                ...
# 6907        6907  Tcn16639                                      worldtruth.tv
# 6908        6908  Tcn16640                                      worldtruth.tv
# 6909        6909  Tcn16641                                      worldtruth.tv
# 6910        6910  Tcn16642                              wundergroundmusic.com
# 6911        6911  Tcn16643                              wundergroundmusic.com
#
# ...

# %%
target = target.drop(columns = ['Unnamed: 0'])

target
# Out:
#             ID                                         Target_url  \
# 0         Tcn0  https://www.nytimes.com/2016/11/22/us/politics...
# 1         Tcn2  https://www.nytimes.com/2016/11/12/us/politics...
# 2         Tcn3  https://www.nytimes.com/2016/10/21/business/in...
# 3         Tcn4  https://www.nytimes.com/2016/11/21/us/politics...
# 4         Tcn5  https://www.nytimes.com/2016/11/19/us/politics...
# ...        ...                                                ...
# 6907  Tcn16639                                      worldtruth.tv
# 6908  Tcn16640                                      worldtruth.tv
# 6909  Tcn16641                                      worldtruth.tv
# 6910  Tcn16642                              wundergroundmusic.com
# 6911  Tcn16643                              wundergroundmusic.com
#
#                                             Target_text  \
# 0     They stood in line at Trump Tower, sometimes u...
# 1     President-elect Donald J. Trump won the White ...
# ...

# %%
target.to_csv('Dataset/Data/Target/TICNN.csv')

# %%
source = pd.read_csv('Dataset/Initial_Data/Source/TICNN.csv')

source
# Out:
#       Unnamed: 0        ID  numSources  \
# 0              0      Tcn0           2
# 1              1      Tcn2           3
# 2              2      Tcn3           4
# 3              3      Tcn4           4
# 4              4      Tcn5           4
# ...          ...       ...         ...
# 6907        6907  Tcn16639           4
# 6908        6908  Tcn16640           2
# 6909        6909  Tcn16641           4
# 6910        6910  Tcn16642           3
# 6911        6911  Tcn16643           3
#
#                                             Source_url1  \
# 0                 https://en.wikipedia.org/wiki/Leisure
# 1             https://en.wikipedia.org/wiki/Daylighting
# 2     https://www.nytimes.com/2016/10/21/business/in...
# 3     https://time.com/president-donald-trump-inaugu...
# 4     https://www.washingtonpost.com/world/asia_paci...
# ...                                                 ...
# 6907                https://aces.nmsu.edu/pubs/_h/H221/
# ...

# %%
similarity = pd.read_csv('Dataset/Initial_Data/ImageSimilarities_TICNN.csv')

similarity
# Out:
#       Unnamed: 0        ID                                            Source1  \
# 0              0      Tcn0  [{'Similarity': 0.27929056, 'Index': 1}, {'Sim...
# 1              1      Tcn2  [{'Similarity': 0.39900738, 'Index': 8}, {'Sim...
# 2              2      Tcn3  [{'Similarity': 0.9918765, 'Index': 0}, {'Simi...
# 3              3      Tcn4  [{'Similarity': 0.57976675, 'Index': 0}, {'Sim...
# 4              4      Tcn5                                                 []
# ...          ...       ...                                                ...
# 6907        6907  Tcn16639                                                 []
# 6908        6908  Tcn16640  [{'Similarity': 0.34813175, 'Index': 1}, {'Sim...
# 6909        6909  Tcn16641           [{'Similarity': 0.38964844, 'Index': 0}]
# 6910        6910  Tcn16642  [{'Similarity': 0.97826016, 'Index': 8}, {'Sim...
# 6911        6911  Tcn16643           [{'Similarity': 0.15020028, 'Index': 1}]
#
# ...

# %%
similarity = similarity.iloc[:,:].values

# %%
for i in range(len(similarity)):
    
    for j in range(2,6):
        
        similarity[i][j] = literal_eval(similarity[i][j])
        
        name = 'Image_url' + str(j-1)
        
        source[name][i] = literal_eval(source[name][i])
        
        temp = {}
        
        if len(similarity[i][j])>0:
            temp['image_name'] = source['ID'][i] + '_' + str(j-1) + '_' + str(similarity[i][j][0]['Index']) + '.jpg'
            temp['image_url'] = source[name][i][similarity[i][j][0]['Index']]
            source[name][i] = temp
        else:
            source[name][i] = []
# Out:
# C:\Users\Pawan\anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\Pawan\anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# C:\Users\Pawan\anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
source
# Out:
#       Unnamed: 0        ID  numSources  \
# 0              0      Tcn0           2
# 1              1      Tcn2           3
# 2              2      Tcn3           4
# 3              3      Tcn4           4
# 4              4      Tcn5           4
# ...          ...       ...         ...
# 6907        6907  Tcn16639           4
# 6908        6908  Tcn16640           2
# 6909        6909  Tcn16641           4
# 6910        6910  Tcn16642           3
# 6911        6911  Tcn16643           3
#
#                                             Source_url1  \
# 0                 https://en.wikipedia.org/wiki/Leisure
# 1             https://en.wikipedia.org/wiki/Daylighting
# 2     https://www.nytimes.com/2016/10/21/business/in...
# 3     https://time.com/president-donald-trump-inaugu...
# 4     https://www.washingtonpost.com/world/asia_paci...
# ...                                                 ...
# 6907                https://aces.nmsu.edu/pubs/_h/H221/
# ...

# %%
source = source.drop(columns = ['Unnamed: 0'])

source
# Out:
#             ID  numSources                                        Source_url1  \
# 0         Tcn0           2              https://en.wikipedia.org/wiki/Leisure
# 1         Tcn2           3          https://en.wikipedia.org/wiki/Daylighting
# 2         Tcn3           4  https://www.nytimes.com/2016/10/21/business/in...
# 3         Tcn4           4  https://time.com/president-donald-trump-inaugu...
# 4         Tcn5           4  https://www.washingtonpost.com/world/asia_paci...
# ...        ...         ...                                                ...
# 6907  Tcn16639           4                https://aces.nmsu.edu/pubs/_h/H221/
# 6908  Tcn16640           2              https://en.wikipedia.org/wiki/Leisure
# 6909  Tcn16641           4         https://en.wikipedia.org/wiki/Spokesperson
# 6910  Tcn16642           3  https://www.gp.se/kultur/axwell-kommer-till-g%...
# 6911  Tcn16643           3  https://dict.longdo.com/search/-%E0%B9%84%E0%B...
#
# ...

# %%
source.to_csv('Dataset/Data/Source/TICNN.csv')
